# %%
from PIL import Image

# %%
def show_img(info, ratio = 0.3):
    info = info.split()
    path = info[0].split("/")[-1]
    path = "D:/dataset/morph/Album2/"+path
    img = Image.open(path)
    img = img.resize((int(img.size[0]*ratio), int(img.size[1]*ratio)))
    display(img)
    print("Real Age:", info[1], "\t Pred Age:", info[2], "\tAbsolute Error:", info[3])

# %% [markdown]
# # Morph
# epoch049_Morph_0.02445_2.3280_20200809_se_resnext50_32x4d_ldl.pth

# %% [markdown]
# ## Some of the greatest errors

# %%
show_img("../dataset/morph/Album2/306916_01M45.JPG	45	22.14410973	22.85589027")
show_img("../dataset/morph/Album2/167974_00F42.JPG	42	22.21206093	19.78793907")
show_img("../dataset/morph/Album2/019066_08M70.JPG	70	50.60540771	19.39459229")
show_img("../dataset/morph/Album2/153128_02M33.JPG	33	51.46770859	18.46770859")
show_img("../dataset/morph/Album2/330089_03F38.JPG	38	20.55652428	17.44347572")
# Out:
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEFF3BEB8>
# Real Age: 45 	 Pred Age: 22.14410973 	Absolute Error: 22.85589027
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEFF3BD68>
# Real Age: 42 	 Pred Age: 22.21206093 	Absolute Error: 19.78793907
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEFF3BE80>
# Real Age: 70 	 Pred Age: 50.60540771 	Absolute Error: 19.39459229
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEF8B7470>
# Real Age: 33 	 Pred Age: 51.46770859 	Absolute Error: 18.46770859
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEFF3BEB8>
# Real Age: 38 	 Pred Age: 20.55652428 	Absolute Error: 17.44347572

# %% [markdown]
# ## Success pred

# %%
show_img("../dataset/morph/Album2/333484_02M47.JPG	47	46.99897385	0.001026154")
show_img("../dataset/morph/Album2/351350_01M22.JPG	22	22.00216484	0.002164841")
# Out:
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEF042F98>
# Real Age: 47 	 Pred Age: 46.99897385 	Absolute Error: 0.001026154
# <PIL.Image.Image image mode=RGB size=120x144 at 0x21EEF0426A0>
# Real Age: 22 	 Pred Age: 22.00216484 	Absolute Error: 0.002164841

# %% [markdown]
# # Megaage_asian
#
# ## Some of the greatest errors

# %%
def show_img(info, ratio = 0.3):
    info = info.split()
    path = info[0].split("/")[-1]
    path = "D:/dataset//"+path
    img = Image.open(path)
    img = img.resize((int(img.size[0]*ratio), int(img.size[1]*ratio)))
    display(img)
    print("Real Age:", info[1], "\t Pred Age:", info[2], "\tAbsolute Error:", info[3])

# %%
def newshow(k):
    show_img(k, ratio = 0.7)
newshow("../dataset/megaage_asian/test/3464.jpg	53	26.18750763	26.81249237")
newshow("../dataset/megaage_asian/test/1245.jpg	24	5.860284328	18.13971519")
newshow("../dataset/megaage_asian/test/276.jpg	8	25.86382675	17.86382675")
newshow("../dataset/megaage_asian/test/3419.jpg	49	31.43752289	17.56247711")
newshow("../dataset/megaage_asian/test/1154.jpg	21	3.600367069	17.39963341")
# Out:
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEF0422E8>
# Real Age: 53 	 Pred Age: 26.18750763 	Absolute Error: 26.81249237
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEFF3B048>
# Real Age: 24 	 Pred Age: 5.860284328 	Absolute Error: 18.13971519
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEF0422E8>
# Real Age: 8 	 Pred Age: 25.86382675 	Absolute Error: 17.86382675
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEFAA6C18>
# Real Age: 49 	 Pred Age: 31.43752289 	Absolute Error: 17.56247711
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEFF3BAC8>
# Real Age: 21 	 Pred Age: 3.600367069 	Absolute Error: 17.39963341

# %% [markdown]
# ## successful case

# %%
newshow("../dataset/megaage_asian/test/2347.jpg	28	28.00002289	2.29E-05")
newshow("../dataset/megaage_asian/test/79.jpg	1	0.99874723	0.00125277")
newshow("../dataset/megaage_asian/test/2631.jpg,29,36.04912185668945,7.049121856689453")
# Out:
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEFAA6BE0>
# Real Age: 28 	 Pred Age: 28.00002289 	Absolute Error: 2.29E-05
# <PIL.Image.Image image mode=RGB size=124x152 at 0x21EEFF3B048>
# Real Age: 1 	 Pred Age: 0.99874723 	Absolute Error: 0.00125277
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-0f97714ed00d> in <module>
#       1 newshow("../dataset/megaage_asian/test/2347.jpg 28      28.00002289     2.29E-05")
#       2 newshow("../dataset/megaage_asian/test/79.jpg   1       0.99874723      0.00125277")
# ----> 3 newshow("../dataset/megaage_asian/test/2631.jpg,29,36.04912185668945,7.049121856689453")
#
# <ipython-input-46-afcdc7b28e72> in newshow(k)
#       1 def newshow(k):
# ----> 2     show_img(k, ratio = 0.7)
#       3 newshow("../dataset/megaage_asian/test/3464.jpg 53      26.18750763     26.81249237")
# ...

# %% [markdown]
# ## Error < 5

# %%
newshow("../dataset/megaage_asian/test/527.jpg,10,5.011333465576172,4.988666534423828")
newshow("../dataset/megaage_asian/test/1335.jpg,22,17.24428939819336,4.755710601806641")
newshow("../dataset/megaage_asian/test/1182.jpg,23,19.791751861572266,3.2082481384277344")
# Out:
# <PIL.Image.Image image mode=RGB size=124x152 at 0x2ABA5EE54670>
# Real Age: 10 	 Pred Age: 5.011333465576172 	Absolute Error: 4.988666534423828
# <PIL.Image.Image image mode=RGB size=124x152 at 0x2ABA5EE54D30>
# Real Age: 22 	 Pred Age: 17.24428939819336 	Absolute Error: 4.755710601806641
# <PIL.Image.Image image mode=RGB size=124x152 at 0x2ABA5EE54670>
# Real Age: 23 	 Pred Age: 19.791751861572266 	Absolute Error: 3.2082481384277344
